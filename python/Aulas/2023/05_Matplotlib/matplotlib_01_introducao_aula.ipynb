# %% [markdown]
# # Matplotlib

# %% [markdown]
# - Biblioteca popular para visualização e geração de gráficos, histogramas e outras visualizações profissionais;
# - Possui recursos interativos como zoom e visão panorâmica, além de possibilitar exportar as imagens para vários formatos como vetor comum, pdf, svg, jpg, png, bmp, gif, entre outros.

# %% [markdown]
# Site Oficial: https://matplotlib.org/
#
# Documentação: https://matplotlib.org/stable/index.html
#
# Passos iniciais: https://matplotlib.org/stable/users/explain/quick_start.html
#
# Instalação: pip install matplotlib

# %%
import matplotlib as mpl

# %%
import matplotlib.pyplot as plt

# %%
''' 
Se o gráfico abrir em uma nova janela, deve 
usar o comando a seguir para forçar que ele abra
no próprio jupyter
'''
# %matplotlib inline

# %% [markdown]
# ## plot()
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html

# %%
x = [1,2,3,4,5]
y = [-2,5,200,50,-24]
plt.plot(x,y)
plt.show()

# %% [markdown]
# ### Legendas

# %%
x = [1,2,3,4,5]
y = [-2,5,200,50,-24]
plt.plot(x,y, label="Notas")
plt.legend()
plt.show()

# %%
x = [1,2,3,4,5]
y = [-2,5,200,50,-24]
plt.plot(x,y, label="Notas")
plt.legend()
plt.xlabel("Nome do Eixo x")
plt.ylabel("Nome do Eixo y")
plt.show()

# %% [markdown]
# ### Escala

# %%
plt.plot(x,y, label="Notas")
plt.legend()
plt.xlabel("Nome do Eixo x")
plt.ylabel("Nome do Eixo y")
plt.xticks([1,3,5,7])
plt.yticks([-30,0,30,60,90,120,150,180,210])
plt.show()

# %% [markdown]
# ### Propriedades de Linha
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.lines.Line2D.html

# %%
plt.plot(x,y, label="Notas", linestyle="dashed")
plt.legend()
plt.xlabel("Nome do Eixo x")
plt.ylabel("Nome do Eixo y")
plt.xticks([1,3,5,7])
plt.yticks([-30,0,30,60,90,120,150,180,210])
plt.show()

# %%
plt.plot(x,y, label="Notas", linestyle="dashed", color="#781001")
plt.legend()
plt.xlabel("Nome do Eixo x")
plt.ylabel("Nome do Eixo y")
plt.xticks([1,3,5,7])
plt.yticks([-30,0,30,60,90,120,150,180,210])
plt.show()

# %%
plt.plot(x,y, label="Notas", linestyle="dashed", color="#781001", linewidth="3")
plt.legend()
plt.xlabel("Nome do Eixo x")
plt.ylabel("Nome do Eixo y")
plt.xticks([1,3,5,7])
plt.yticks([-30,0,30,60,90,120,150,180,210])
plt.show()

# %%
plt.plot(x,y, label="Notas", linestyle="dashed", color="#781001", linewidth="3")
plt.legend()
plt.xlabel("Nome do Eixo x")
plt.ylabel("Nome do Eixo y")
plt.xticks([1,3,5,7])
plt.yticks([-30,0,30,60,90,120,150,180,210])
plt.title("Gráfico da Aula")
plt.show()

# %% [markdown]
# ## Tipos de Gráficos

# %% [markdown]
# ### scatter - gráfico de dispersão
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html

# %%
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ### bar - gráfico de barras
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html

# %%
plt.bar(x,y)
plt.show()

# %% [markdown]
# ### pie - gráfico de pizza
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.pie.html

# %%
z = [23,5,100,2]
plt.pie(z)
plt.show()

# %% [markdown]
# ## Mudando o tipo de marcador do gráfico
#
# https://matplotlib.org/stable/api/markers_api.html

# %%
plt.scatter(x,y, marker="v")
plt.show()

# %% [markdown]
# ## Mudando os limites do gráfico
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.axis.html

# %%
plt.plot(x,y)
plt.axis(xmin=-1,xmax=8,ymin=-50,ymax=300)
plt.show()

# %%
plt.plot(x,y)
plt.axis("square")
plt.show()

# %% [markdown]
# ## Na prática - dataset Pokemon e UFO

# %%
import pandas as pd
pokemon = pd.read_csv('Pokemon.csv')
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pokemon_attack = pokemon[['Name','Attack']]
pokemon_attack
# Out:
#                       Name  Attack
# 0                Bulbasaur      49
# 1                  Ivysaur      62
# 2                 Venusaur      82
# 3    VenusaurMega Venusaur     100
# 4               Charmander      52
# ..                     ...     ...
# 795                Diancie     100
# 796    DiancieMega Diancie     160
# 797    HoopaHoopa Confined     110
# 798     HoopaHoopa Unbound     160
# 799              Volcanion     110
#
# [800 rows x 2 columns]

# %%
x = pokemon_attack['Name']
y = pokemon_attack['Attack']
plt.bar(x,y)
plt.show()

# %%
# 6 Pokemons com os maiores Attack
pokemon_maiores = pokemon_attack.sort_values('Attack', ascending=False).head(6)
x = pokemon_maiores['Name']
y = pokemon_maiores['Attack']
plt.bar(x,y)
plt.show()

# %%
# 6 Pokemons com os maiores Attack
pokemon_maiores = pokemon_attack.sort_values('Attack', ascending=False).head(6)
x = pokemon_maiores['Name']
y = pokemon_maiores['Attack']
plt.figure(figsize=(15,5))
plt.bar(x,y)
plt.show()

# %%
pokemon_maiores = pokemon_attack.sort_values('Attack', ascending=False).head(6)
x = pokemon_maiores['Name']
y = pokemon_maiores['Attack']
plt.bar(x,y)
plt.xticks(rotation=50, ha='right')
plt.show()

# %%
# Inserir Attack e Defense dos 5 primeiros Pokemons no mesmo gráfico
y_attack = pokemon['Attack'].head(5)
y_defense = pokemon['Defense'].head(5)
x = pokemon['Name'].head(5)
plt.plot(x, y_attack, label='Attack')
plt.plot(x, y_defense, label='Defense')
plt.legend()
plt.show()

# %%
# Inserir Attack e Defense dos 5 primeiros Pokemons no mesmo gráfico
y_attack = pokemon['Attack']
y_defense = pokemon['Defense']
x = pokemon['Name']
plt.scatter(x, y_attack, label='Attack')
plt.scatter(x, y_defense, label='Defense')
plt.legend()
plt.show()
