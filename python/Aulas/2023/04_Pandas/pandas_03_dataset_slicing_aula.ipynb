# %% [markdown]
# # Pandas

# %% [markdown]
# ## Leitura de Dataset

# %%
import pandas as pd

# %%
dataframe_1 = pd.read_csv('Pokemon.csv')

# %%
dataframe_1
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
dataframe_2 = pd.read_table('Pokemon.csv', sep=',')
dataframe_2
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# ## Slicing

# %% [markdown]
# ### Linhas

# %%
dataframe_2[2:6]
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
# 5  5             Charmeleon   Fire     NaN    405  58      64       58
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False

# %%
dataframe_2[10:]
# Out:
#        #                     Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 10     8                Wartortle    Water    NaN    405  59      63       80
# 11     9                Blastoise    Water    NaN    530  79      83      100
# 12     9  BlastoiseMega Blastoise    Water    NaN    630  79     103      120
# 13    10                 Caterpie      Bug    NaN    195  45      30       35
# 14    11                  Metapod      Bug    NaN    205  50      20       55
# ..   ...                      ...      ...    ...    ...  ..     ...      ...
# 795  719                  Diancie     Rock  Fairy    600  50     100      150
# 796  719      DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720      HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720       HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721                Volcanion     Fire  Water    600  80     110      120
#
# ...

# %%
dataframe_2[1:20:2]
# Out:
#      #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 1    2                    Ivysaur  Grass  Poison    405  60      62       63
# 3    3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 5    5                 Charmeleon   Fire     NaN    405  58      64       58
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 9    7                   Squirtle  Water     NaN    314  44      48       65
# 11   9                  Blastoise  Water     NaN    530  79      83      100
# 13  10                   Caterpie    Bug     NaN    195  45      30       35
# 15  12                 Butterfree    Bug  Flying    395  60      45       50
# 17  14                     Kakuna    Bug  Poison    205  45      25       50
# 19  15      BeedrillMega Beedrill    Bug  Poison    495  65     150       40
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 1        80       80     60           1      False
# ...

# %%
dataframe_2[::5]
# Out:
#        #                   Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur   Grass  Poison    318  45      49       49
# 5      5             Charmeleon    Fire     NaN    405  58      64       58
# 10     8              Wartortle   Water     NaN    405  59      63       80
# 15    12             Butterfree     Bug  Flying    395  60      45       50
# 20    16                 Pidgey  Normal  Flying    251  40      45       40
# ..   ...                    ...     ...     ...    ...  ..     ...      ...
# 775  705                Sliggoo  Dragon     NaN    452  68      75       53
# 780  710  PumpkabooAverage Size   Ghost   Grass    335  49      66       70
# 785  711    GourgeistSmall Size   Ghost   Grass    494  55      85      122
# 790  714                 Noibat  Flying  Dragon    245  40      30       35
# 795  719                Diancie    Rock   Fairy    600  50     100      150
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ### Linhas x Colunas

# %%
dataframe_2.loc[5:10,'Total':'Defense']
# Out:
#     Total  HP  Attack  Defense
# 5     405  58      64       58
# 6     534  78      84       78
# 7     634  78     130      111
# 8     634  78     104       78
# 9     314  44      48       65
# 10    405  59      63       80

# %%
dataframe_2.loc[5:10,'Total':]
# Out:
#     Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 5     405  58      64       58       80       65     80           1      False
# 6     534  78      84       78      109       85    100           1      False
# 7     634  78     130      111      130       85    100           1      False
# 8     634  78     104       78      159      115    100           1      False
# 9     314  44      48       65       50       64     43           1      False
# 10    405  59      63       80       65       80     58           1      False

# %%
dataframe_2.loc[:,'Total':'Attack']
# Out:
#      Total  HP  Attack
# 0      318  45      49
# 1      405  60      62
# 2      525  80      82
# 3      625  80     100
# 4      309  39      52
# ..     ...  ..     ...
# 795    600  50     100
# 796    700  50     160
# 797    600  80     110
# 798    680  80     160
# 799    600  80     110
#
# [800 rows x 3 columns]

# %%
dataframe_2.loc[:,['Total','Speed']]
# Out:
#      Total  Speed
# 0      318     45
# 1      405     60
# 2      525     80
# 3      625     80
# 4      309     65
# ..     ...    ...
# 795    600     50
# 796    700    110
# 797    600     70
# 798    680     80
# 799    600     70
#
# [800 rows x 2 columns]

# %% [markdown]
# ### Linhas x Colunas (índices)
